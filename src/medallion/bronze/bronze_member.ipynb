# %%
# %run ../../config/utils

# %%
import sys
sys.path.append("..")
sys.path.append("../..")

from lib.job_manager import load_config, split_config
from lib_etl.s3 import etl_input_data_validator
import lib_etl.validations_ETL as validations

# %%
config = load_config(etl_config_path)
data_paths, club_square_config, config_validation = split_config(config)

# %% [markdown]
# ## Data availability check

# %%
source_path = data_paths["source"]["member"]
recency_lookback_duration = data_paths.get("recency_lookback_duration", {})
etl_input_data_validator(
    "source",
    recency_lookback_duration,
    data_paths,
    [
        "member",
    ],
    spark
)

# %% [markdown]
# ## Load source data

# %%
df = spark.read.csv(source_path, header=False, sep='|', quote='"')
df.createOrReplaceTempView('df')

# %%
validations.validate_table(
        spark, "source", 'member', config_validation, df, stats_etl_path
    )

# %% [markdown]
# ## Save to delta table

# %%
spark.sql(f"""
    INSERT OVERWRITE {bronze_master_member}
    SELECT
        _c0,
        _c1,
        _c2,
        _c3,
        _c4,
        _c5,
        _c6,
        _c7
    FROM df
""")
